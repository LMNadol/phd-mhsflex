# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from __future__ import annotations
import numpy as np

from matplotlib import rc, colors, ticker
import matplotlib.pyplot as plt

from sunpy.net import Fido, attrs as a
import astropy.units as u
from astropy.io import fits
from astropy.visualization import astropy_mpl_style
from astropy.coordinates import SkyCoord
import sunpy.map
from matplotlib.patches import ConnectionPatch
from matplotlib import colors


rc("font", **{"family": "serif", "serif": ["Times"]})
rc("text", usetex=True)

c4 = (1.000, 0.224, 0.376)
c1 = (0.439, 0.788, 1.000)
c3 = "black"
c2 = (0.420, 0.502, 1.000)

cmap = colors.LinearSegmentedColormap.from_list(
    "cmap",
    (
        (0.000, (0.000, 0.000, 0.000)),
        (0.500, (0.659, 0.659, 0.659)),
        (1.000, (1.000, 1.000, 1.000)),
    ),
)

cmap2 = colors.LinearSegmentedColormap.from_list(
    "cmap2", ((0.000, (0.984, 1.000, 0.000)), (1.000, (1.000, 0.988, 0.761)))
)

# %%
folder="/Users/lilli/Desktop/Thesis/May2024_flare/sunspot"

# %%
result = Fido.search(
    a.Time("2024/5/6 14:00:00", "2024/5/6 14:01:00"),
    a.Instrument.hmi,
    a.Physobs("intensity"),
)

# %%
result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x171cf2bd0>
# Results from 1 Provider:
#
# 1 Results from the VSOClient:
# Source: http://vso.stanford.edu/cgi-bin/search
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- --------
# 2024-05-06 14:00:35.000 2024-05-06 14:00:36.000    SDO ...    FULLDISK -0.00098

# %%
files = Fido.fetch(result[:, 0], path=folder + "/{file}")
# Out:
# Files Downloaded: 100%|██████████| 1/1 [00:15<00:00, 15.54s/file]

# %%
path = "/Users/lilli/Desktop/Thesis/May2024_flare/sunspot/hmi_ic_45s_2024_05_06_14_01_30_tai_continuum.fits"
hmi_image = sunpy.map.Map(path).rotate()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=hmi_image)
hmi_image.plot()

plt.show()

# %%
top_right = SkyCoord(10 * u.arcsec, -150 * u.arcsec, frame=hmi_image.coordinate_frame)
bottom_left = SkyCoord(-400 * u.arcsec, -350 * u.arcsec, frame=hmi_image.coordinate_frame)
hmi_image_cut = hmi_image.submap(bottom_left, top_right=top_right)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=hmi_image_cut)
image = hmi_image_cut.plot(axes=ax)

# Make some room and put the title at the top of the figure
ax.set_title(ax.get_title(), pad=15)
ax.tick_params(direction="in", length=2, width=0.5)
plotname = folder + "/GOES_Xray_avg1m_2024_May_sunspots_6.png"
plt.savefig(plotname, dpi=300, bbox_inches="tight", pad_inches=0.1)
plt.show()

# %%
result = Fido.search(
    a.Time("2024/5/7 14:00:00", "2024/5/7 14:01:00"),
    a.Instrument.hmi,
    a.Physobs("intensity"),
)

# %%
result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x171dd39e0>
# Results from 1 Provider:
#
# 1 Results from the VSOClient:
# Source: http://vso.stanford.edu/cgi-bin/search
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- --------
# 2024-05-07 14:00:35.000 2024-05-07 14:00:36.000    SDO ...    FULLDISK -0.00098

# %%
files = Fido.fetch(result[:, 0], path=folder + "/{file}")
# Out:
# Files Downloaded: 100%|██████████| 1/1 [00:30<00:00, 30.83s/file]

# %%
path = "/Users/lilli/Desktop/Thesis/May2024_flare/sunspot/hmi_ic_45s_2024_05_07_14_01_30_tai_continuum.fits"
hmi_image = sunpy.map.Map(path).rotate()

# %%
top_right = SkyCoord(220 * u.arcsec, -170 * u.arcsec, frame=hmi_image.coordinate_frame)
bottom_left = SkyCoord(-190 * u.arcsec, -370 * u.arcsec, frame=hmi_image.coordinate_frame)
hmi_image_cut = hmi_image.submap(bottom_left, top_right=top_right)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=hmi_image_cut)
image = hmi_image_cut.plot(axes=ax)

# Make some room and put the title at the top of the figure
ax.set_title(ax.get_title(), pad=15)
ax.tick_params(direction="in", length=2, width=0.5)
plotname = folder + "/GOES_Xray_avg1m_2024_May_sunspots_7.png"
plt.savefig(plotname, dpi=300, bbox_inches="tight", pad_inches=0.1)
plt.show()

# %%
result = Fido.search(
    a.Time("2024/5/8 14:00:00", "2024/5/8 14:01:00"),
    a.Instrument.hmi,
    a.Physobs("intensity"),
)

# %%
result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x17782af90>
# Results from 1 Provider:
#
# 1 Results from the VSOClient:
# Source: http://vso.stanford.edu/cgi-bin/search
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- --------
# 2024-05-08 14:00:35.000 2024-05-08 14:00:36.000    SDO ...    FULLDISK -0.00098

# %%
files = Fido.fetch(result[:, 0], path=folder + "/{file}")
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]2024-09-27 12:45:31 - parfive - INFO: http://netdrms01.nispdc.nso.edu/cgi-bin/netdrms/drms_export.cgi?series=hmi__Ic_45s;compress=rice;record=21988962-21988962 failed to download with exception
#
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# 1/0 files failed to download. Please check `.errors` for details

# %%
path = "/Users/lilli/Desktop/Thesis/May2024_flare/sunspot/hmi_ic_45s_2024_05_08_14_01_30_tai_continuum.fits"
hmi_image = sunpy.map.Map(path).rotate()

# %%
top_right = SkyCoord(430 * u.arcsec, -170 * u.arcsec, frame=hmi_image.coordinate_frame)
bottom_left = SkyCoord(20 * u.arcsec, -370 * u.arcsec, frame=hmi_image.coordinate_frame)
hmi_image_cut = hmi_image.submap(bottom_left, top_right=top_right)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=hmi_image_cut)
image = hmi_image_cut.plot(axes=ax)
ax.tick_params(direction="in", length=2, width=0.5)
# Make some room and put the title at the top of the figure
ax.set_title(ax.get_title(), pad=15)
plotname = folder + "/GOES_Xray_avg1m_2024_May_sunspots_8.png"
plt.savefig(plotname, dpi=300, bbox_inches="tight", pad_inches=0.1)
plt.show()

# %%
result = Fido.search(
    a.Time("2024/5/9 14:00:00", "2024/5/9 14:01:00"),
    a.Instrument.hmi,
    a.Physobs("intensity"),
)

result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x177089dc0>
# Results from 1 Provider:
#
# 1 Results from the VSOClient:
# Source: http://vso.stanford.edu/cgi-bin/search
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- --------
# 2024-05-09 14:00:35.000 2024-05-09 14:00:36.000    SDO ...    FULLDISK -0.00098

# %%
files = Fido.fetch(result[:, 0], path=folder + "/{file}")
# Out:
# Files Downloaded: 100%|██████████| 1/1 [00:14<00:00, 14.09s/file]

# %%
path = "/Users/lilli/Desktop/Thesis/May2024_flare/sunspot/hmi_ic_45s_2024_05_09_14_01_30_tai_continuum.fits"
hmi_image = sunpy.map.Map(path).rotate()

# %%
top_right = SkyCoord(630 * u.arcsec, -170 * u.arcsec, frame=hmi_image.coordinate_frame)
bottom_left = SkyCoord(220 * u.arcsec, -370 * u.arcsec, frame=hmi_image.coordinate_frame)
hmi_image_cut = hmi_image.submap(bottom_left, top_right=top_right)

fig = plt.figure()
ax = fig.add_subplot(projection=hmi_image_cut)
image = hmi_image_cut.plot(axes=ax)
ax.tick_params(direction="in", length=2, width=0.5)
# Make some room and put the title at the top of the figure
ax.set_title(ax.get_title(), pad=15)
plotname = folder + "/GOES_Xray_avg1m_2024_May_sunspots_9.png"
plt.savefig(plotname, dpi=300, bbox_inches="tight", pad_inches=0.1)
plt.show()
